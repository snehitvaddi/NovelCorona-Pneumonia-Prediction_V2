# %% [markdown]
# ## Importing Modules

# %%
import matplotlib.pyplot as plt
import cv2
import glob
import os
import random
import jovian
# Out:
# [jovian] Update Available: 0.2.3 --> 0.2.5
# [jovian] Run `!pip install jovian --upgrade` to upgrade

# %% [markdown]
# ## Note :
# ### <i><h4>My model did not perform as I expected, If anybody tries this and got better metrics than me please feel free to share your knowledge!! After all, Knowledge is Sharing. right!!</h4></i>

# %% [markdown]
# ## <strong>Dataset :</strong>
# You can download dataset from here https://drive.google.com/open?id=1wwXhV2pNJjGdC4dsMz3NQxfhojthUbeB

# %% [markdown]
# ### Data cleaning, naming and Data set Organising

# %%
paths = glob.glob("C:\\Users\\vsneh\\Udemy-notebooks\\covid-19\\dataset\\test\\covid\\*")
i=0
for filename in os.listdir("C:\\Users\\vsneh\\Udemy-notebooks\\covid-19\\dataset\\train\\covid\\"): 
        dst ="train-covid" + str(i) + ".jpg"
        src = "C:\\Users\\vsneh\\Udemy-notebooks\\covid-19\\dataset\\train\\covid\\" + filename 
        dst = "C:\\Users\\vsneh\\Udemy-notebooks\\covid-19\\dataset\\train\\covid\\" + dst 
          
        # rename() function will 
        # rename all the files 
        os.rename(src, dst) 
        i += 1

# %%
os.listdir("C:\\Users\\vsneh\\Udemy-notebooks\\covid-19\\dataset\\test\\covid\\")
# Out:
# ['test-covid0.jpg',
#  'test-covid1.jpg',
#  'test-covid10.jpg',
#  'test-covid11.jpg',
#  'test-covid12.jpg',
#  'test-covid2.jpg',
#  'test-covid3.jpg',
#  'test-covid4.jpg',
#  'test-covid5.jpg',
#  'test-covid6.jpg',
#  'test-covid7.jpg',
#  'test-covid8.jpg',
#  'test-covid9.jpg']

# %%
img1 = cv2.imread('C:\\Users\\vsneh\\Udemy-notebooks\\covid-19\\dataset\\train\\covid\\train-covid7.jpg')
plt.imshow(img1)

# %%
img2 = cv2.imread('C:\\Users\\vsneh\\Udemy-notebooks\\covid-19\\dataset\\train\\normal\\train-normal53.jpg')
plt.imshow(img2)

# %%
img3 = cv2.imread('C:\\Users\\vsneh\\Udemy-notebooks\\covid-19\\dataset\\train\\pneumonia\\train-pneumonia13.jpg')
plt.imshow(img3)

# %%
src_path = "C:\\Users\\vsneh\\Udemy-notebooks\\covid-19\\dataset\\train\\"
sub_class = os.listdir(src_path)

fig = plt.figure(figsize=(10,5))
path = os.path.join(src_path,sub_class[0])

# v = random.sample(range(1, 15), 4)
for i in range(4):
    plt.subplot(240 + 1 + i)
    img = plt.imread(os.path.join(path,'train-covid'+str(i)+'.jpg'))
    plt.imshow(img, cmap=plt.get_cmap('gray'))

path = os.path.join(src_path,sub_class[1])
for i in range(4):
    plt.subplot(240 + 1 + i)
    img = plt.imread(os.path.join(path,'train-normal'+str(i)+'.jpg'))
    plt.imshow(img, cmap=plt.get_cmap('gray'))
    
path = os.path.join(src_path,sub_class[2])
for i in range(4):
    plt.subplot(240 + 1 + i)
    img = plt.imread(os.path.join(path,'train-pneumonia'+str(i)+'.jpg'))
    plt.imshow(img, cmap=plt.get_cmap('gray'))
# Out:
# c:\users\vsneh\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:15: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   from ipykernel import kernelapp as app
# c:\users\vsneh\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:21: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.

# %%
from keras.preprocessing.image import ImageDataGenerator
# Out:
# Using TensorFlow backend.

# %%
image_gen = ImageDataGenerator(rotation_range=30, # rotate the image 30 degrees
                               width_shift_range=0.1, # Shift the pic width by a max of 10%
                               height_shift_range=0.1, # Shift the pic height by a max of 10%
                               rescale=1/255, # Rescale the image by normalzing it.
                               shear_range=0.2, # Shear means cutting away part of the image (max 20%)
                               zoom_range=0.2, # Zoom in by 20% max
                               horizontal_flip=True, # Allo horizontal flipping
                               fill_mode='nearest' # Fill in missing pixels with the nearest filled value
                              )

# %%
plt.imshow(image_gen.random_transform(img1))

# %%
image_gen.flow_from_directory('C:\\Users\\vsneh\\Udemy-notebooks\\covid-19\\dataset\\train')
# Out:
# Found 244 images belonging to 3 classes.

# %%
image_gen.flow_from_directory('C:\\Users\\vsneh\\Udemy-notebooks\\covid-19\\dataset\\test')
# Out:
# Found 55 images belonging to 3 classes.

# %%
image_shape = (150,150,3)

# %%
from keras.models import Sequential
from keras.layers import Activation, Dropout, Flatten, Dense, Conv2D, MaxPool2D

# %%
model = Sequential()
model.add(Conv2D(filters=32,kernel_size=(3,3),input_shape=(150,150,3),activation='relu'))
model.add(MaxPool2D(pool_size=(2,2)))

model.add(Conv2D(filters=64,kernel_size=(3,3),input_shape=(150,150,3),activation='relu'))
model.add(MaxPool2D(pool_size=(2,2)))

model.add(Conv2D(filters=64,kernel_size=(3,3),input_shape=(150,150,3),activation='relu'))
model.add(MaxPool2D(pool_size=(2,2)))

model.add(Flatten())

model.add(Dense(128))
model.add(Activation('relu'))
model.add(Dropout(0.5))

model.add(Dense(3))
model.add(Activation('sigmoid'))

model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_5 (Conv2D)            (None, 148, 148, 32)      896
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 74, 74, 32)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 72, 72, 64)        18496
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 36, 36, 64)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 34, 34, 64)        36928
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 17, 17, 64)        0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 18496)             0
# _________________________________________________________________
# dense_3 (Dense)              (None, 128)               2367616
# _________________________________________________________________
# activation_3 (Activation)    (None, 128)               0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 3)                 387
# _________________________________________________________________
# activation_4 (Activation)    (None, 3)                 0
# =================================================================
# Total params: 2,424,323
# Trainable params: 2,424,323
# Non-trainable params: 0
# _________________________________________________________________

# %%
batch_size = 16

train_image_gen = image_gen.flow_from_directory('C:\\Users\\vsneh\\Udemy-notebooks\\covid-19\\dataset\\train',
                                               target_size=(150,150),
                                               batch_size=batch_size,
                                               class_mode='categorical')
# Out:
# Found 244 images belonging to 3 classes.

# %%
test_image_gen = image_gen.flow_from_directory('C:\\Users\\vsneh\\Udemy-notebooks\\covid-19\\dataset\\test',
                                               target_size=(150,150),
                                               batch_size=batch_size,
                                               class_mode='categorical')
# Out:
# Found 55 images belonging to 3 classes.

# %%
train_image_gen.class_indices
# Out:
# {'covid': 0, 'normal': 1, 'pneumonia': 2}

# %%
import warnings
import PIL.Image
warnings.filterwarnings('ignore')

# %%
results = model.fit_generator(train_image_gen,epochs=15,
                              steps_per_epoch=75,
                              validation_data=test_image_gen,validation_steps=10)
# Out:
# Epoch 1/15
# 75/75 [==============================] - 72s 961ms/step - loss: 0.3298 - accuracy: 0.8558 - val_loss: 0.3063 - val_accuracy: 0.8920
# Epoch 2/15
# 75/75 [==============================] - 77s 1s/step - loss: 0.2964 - accuracy: 0.8727 - val_loss: 0.1387 - val_accuracy: 0.9123
# Epoch 3/15
# 75/75 [==============================] - 73s 974ms/step - loss: 0.3078 - accuracy: 0.8705 - val_loss: 0.1609 - val_accuracy: 0.9460
# Epoch 4/15
# 75/75 [==============================] - 69s 917ms/step - loss: 0.2806 - accuracy: 0.8857 - val_loss: 0.1228 - val_accuracy: 0.9273
# Epoch 5/15
# 75/75 [==============================] - 70s 934ms/step - loss: 0.2706 - accuracy: 0.8942 - val_loss: 0.2645 - val_accuracy: 0.8920
# Epoch 6/15
# 75/75 [==============================] - 59s 788ms/step - loss: 0.2597 - accuracy: 0.8909 - val_loss: 0.1124 - val_accuracy: 0.9724
# Epoch 7/15
# 75/75 [==============================] - 34s 454ms/step - loss: 0.2302 - accuracy: 0.9102 - val_loss: 0.0580 - val_accuracy: 0.9413
# Epoch 8/15
# 75/75 [==============================] - 36s 483ms/step - loss: 0.2372 - accuracy: 0.9013 - val_loss: 0.1183 - val_accuracy: 0.9223
# Epoch 9/15
# 75/75 [==============================] - 35s 467ms/step - loss: 0.2154 - accuracy: 0.9117 - val_loss: 0.1429 - val_accuracy: 0.9225
# Epoch 10/15
# 75/75 [==============================] - 35s 464ms/step - loss: 0.2301 - accuracy: 0.9067 - val_loss: 0.2086 - val_accuracy: 0.9749
# Epoch 11/15
# 75/75 [==============================] - 80s 1s/step - loss: 0.2171 - accuracy: 0.9187 - val_loss: 0.0931 - val_accuracy: 0.9554
# Epoch 12/15
# 75/75 [==============================] - 91s 1s/step - loss: 0.2107 - accuracy: 0.9144 - val_loss: 0.0341 - val_accuracy: 0.9524
# Epoch 13/15
# 75/75 [==============================] - 51s 675ms/step - loss: 0.2051 - accuracy: 0.9234 - val_loss: 0.0665 - val_accuracy: 0.9296
# Epoch 14/15
# 75/75 [==============================] - 44s 583ms/step - loss: 0.1914 - accuracy: 0.9269 - val_loss: 0.1647 - val_accuracy: 0.9223
# Epoch 15/15
# 75/75 [==============================] - 42s 558ms/step - loss: 0.1929 - accuracy: 0.9239 - val_loss: 0.0316 - val_accuracy: 0.9531

# %%
results.history['accuracy']
# Out:
# [0.8558477,
#  0.8726852,
#  0.8704678,
#  0.88567245,
#  0.8941521,
#  0.8909145,
#  0.9102342,
#  0.90133095,
#  0.9116961,
#  0.9067252,
#  0.9187134,
#  0.914352,
#  0.92339176,
#  0.92690074,
#  0.92390037]

# %%
plt.plot(results.history['loss'])

# %%
plt.plot(results.history['accuracy'])
plt.plot(results.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
plt.plot(results.history['loss'])
plt.plot(results.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# ## External Image prediction

# %%
train_image_gen.class_indices
# Out:
# {'covid': 0, 'normal': 1, 'pneumonia': 2}

# %%
import numpy as np
from keras.preprocessing import image
coropos = 'C:\\Users\\vsneh\\Udemy-notebooks\\covid-19\\dataset\\corona-ptve.png'
img = image.load_img(coropos,target_size=(150,150))
img = image.img_to_array(img)
img = img/255

# %%
prediction = model.predict_classes(img.reshape(1,150,150,3))

# %%
prediction
# Out:
# array([0], dtype=int64)

# %%
import numpy as np
from keras.preprocessing import image
coropos = 'C:\\Users\\vsneh\\Udemy-notebooks\\covid-19\\dataset\\pneumo-ptve.jpg'
img = image.load_img(coropos,target_size=(150,150))
img = image.img_to_array(img)
img = img/255
prediction = model.predict_classes(img.reshape(1,150,150,3))
print(prediction)
# Out:
# [0]

# %%
jovian.commit()
# Out:
# [jovian] Attempting to save notebook..
